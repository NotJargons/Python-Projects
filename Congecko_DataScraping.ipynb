# %%
import pandas as pd

# %%
from bs4 import BeautifulSoup
import requests

# %%
#Inputing the website to be scraped : Coingecko: Top 100 CryptoCurrencies 

url = 'https://www.coingecko.com/'
page = requests.get(url)
soup = BeautifulSoup(page.text, 'html')

# %%
table = soup.find_all('table')[0]

# %%
titles = table.find_all('th')

# %%
table_titles =[title.text.strip() for title in titles[1:]]

# %%
print(table_titles)
# Out:
# ['#', 'Coin', '', 'Price', '1h', '24h', '7d', '30d', '24h Volume', 'Market Cap', 'FDV', 'Market Cap / FDV', 'Last 7 Days', '']

# %%
del df ['Last 7 Days']

# %%
df2 = df.rename(columns ={'':'Action'})

# %%
df2
# Out:
# Empty DataFrame
# Columns: [#, Coin, Action, Price, 1h, 24h, 7d, 30d, 24h Volume, Market Cap, FDV, Market Cap / FDV, Action]
# Index: []

# %%
column_data = table.find_all('tr')

# %%
for row in column_data[2:]:
    row_data = row.find_all('td')
    individual_row_data = [data.text.strip() for data in row_data[1:]]
    
#Syncing the result to the dataframe
    
    length = len(df2)
    df2.loc[length] = individual_row_data

# %%
df2
# Out:
#       #                      Coin Action       Price    1h   24h     7d  \
# 0     1            Bitcoin\n\nBTC    Buy  $60,597.66  0.5%  1.9%  11.7%
# 1     2           Ethereum\n\nETH    Buy   $2,963.90  0.1%  1.3%  14.8%
# 2     3            Tether\n\nUSDT    Buy       $1.00  0.2%  0.3%   0.2%
# 3     4                BNB\n\nBNB    Buy     $520.19  0.9%  1.0%  12.1%
# 4     5             Solana\n\nSOL    Buy     $129.39  0.4%  1.9%  22.9%
# ..  ...                       ...    ...         ...   ...   ...    ...
# 95   94          Worldcoin\n\nWLD              $4.79  1.8%  3.4%  26.0%
# 96   97  Synthetix Network\n\nSNX    Buy       $2.75  0.2%  1.4%  28.0%
# 97   99                Gate\n\nGT              $6.67  1.2%  0.2%  15.1%
# 98  101            Conflux\n\nCFX            $0.2232  0.4%  0.7%  35.1%
# 99   98          Starknet\n\nSTRK              $1.21  0.3%  2.0%  34.7%
#
#       30d       24h Volume          Market Cap                 FDV  \
# 0   10.0%  $34,166,963,622  $1,196,409,667,144  $1,276,308,914,717
# 1   15.8%  $16,411,225,877    $356,887,641,666    $356,887,641,666
# 2    0.1%  $62,763,221,768    $108,935,986,564    $108,935,986,564
# 3    5.8%   $1,588,219,925     $80,321,183,881     $80,321,183,881
# 4   36.2%   $5,037,552,943     $57,901,634,688     $74,417,366,096
# ..    ...              ...                 ...                 ...
# 95  46.1%     $333,615,649        $905,596,275     $47,879,776,889
# 96  29.8%      $37,882,502        $902,820,408        $903,988,037
# 97   3.8%      $10,085,895        $893,073,560      $2,005,577,636
# 98  44.0%      $58,577,760        $885,480,117      $1,233,059,229
# 99  38.4%     $117,486,418        $878,962,760     $12,073,664,284
#
#    Market Cap / FDV Action
# 0              0.94
# 1               1.0
# 2               1.0
# 3               1.0
# 4              0.78
# ..              ...    ...
# 95             0.02
# 96              1.0
# 97             0.45
# 98             0.72
# 99             0.07
#
# [100 rows x 13 columns]

# %%
#Deleting Unused columns

del df2 ['Action']

# %%
#Splitting the Coin Column into Coin & Currency Code

df2[['Coin','Currency Code']] = df2['Coin'].str.split("\n\n", expand = True)

# %%
df2
# Out:
#       #               Coin       Price    1h   24h     7d    30d  \
# 0     1            Bitcoin  $60,597.66  0.5%  1.9%  11.7%  10.0%
# 1     2           Ethereum   $2,963.90  0.1%  1.3%  14.8%  15.8%
# 2     3             Tether       $1.00  0.2%  0.3%   0.2%   0.1%
# 3     4                BNB     $520.19  0.9%  1.0%  12.1%   5.8%
# 4     5             Solana     $129.39  0.4%  1.9%  22.9%  36.2%
# ..  ...                ...         ...   ...   ...    ...    ...
# 95   94          Worldcoin       $4.79  1.8%  3.4%  26.0%  46.1%
# 96   97  Synthetix Network       $2.75  0.2%  1.4%  28.0%  29.8%
# 97   99               Gate       $6.67  1.2%  0.2%  15.1%   3.8%
# 98  101            Conflux     $0.2232  0.4%  0.7%  35.1%  44.0%
# 99   98           Starknet       $1.21  0.3%  2.0%  34.7%  38.4%
#
#          24h Volume          Market Cap                 FDV Market Cap / FDV  \
# 0   $34,166,963,622  $1,196,409,667,144  $1,276,308,914,717             0.94
# 1   $16,411,225,877    $356,887,641,666    $356,887,641,666              1.0
# 2   $62,763,221,768    $108,935,986,564    $108,935,986,564              1.0
# 3    $1,588,219,925     $80,321,183,881     $80,321,183,881              1.0
# 4    $5,037,552,943     $57,901,634,688     $74,417,366,096             0.78
# ..              ...                 ...                 ...              ...
# 95     $333,615,649        $905,596,275     $47,879,776,889             0.02
# 96      $37,882,502        $902,820,408        $903,988,037              1.0
# 97      $10,085,895        $893,073,560      $2,005,577,636             0.45
# 98      $58,577,760        $885,480,117      $1,233,059,229             0.72
# 99     $117,486,418        $878,962,760     $12,073,664,284             0.07
#
#    Currency Code
# 0            BTC
# 1            ETH
# 2           USDT
# 3            BNB
# 4            SOL
# ..           ...
# 95           WLD
# 96           SNX
# 97            GT
# 98           CFX
# 99          STRK
#
# [100 rows x 12 columns]

# %%
#Changing empty set to Null, if present

df2.fillna("Null")
# Out:
#       #               Coin       Price    1h   24h     7d    30d  \
# 0     1            Bitcoin  $60,597.66  0.5%  1.9%  11.7%  10.0%
# 1     2           Ethereum   $2,963.90  0.1%  1.3%  14.8%  15.8%
# 2     3             Tether       $1.00  0.2%  0.3%   0.2%   0.1%
# 3     4                BNB     $520.19  0.9%  1.0%  12.1%   5.8%
# 4     5             Solana     $129.39  0.4%  1.9%  22.9%  36.2%
# ..  ...                ...         ...   ...   ...    ...    ...
# 95   94          Worldcoin       $4.79  1.8%  3.4%  26.0%  46.1%
# 96   97  Synthetix Network       $2.75  0.2%  1.4%  28.0%  29.8%
# 97   99               Gate       $6.67  1.2%  0.2%  15.1%   3.8%
# 98  101            Conflux     $0.2232  0.4%  0.7%  35.1%  44.0%
# 99   98           Starknet       $1.21  0.3%  2.0%  34.7%  38.4%
#
#          24h Volume          Market Cap                 FDV Market Cap / FDV  \
# 0   $34,166,963,622  $1,196,409,667,144  $1,276,308,914,717             0.94
# 1   $16,411,225,877    $356,887,641,666    $356,887,641,666              1.0
# 2   $62,763,221,768    $108,935,986,564    $108,935,986,564              1.0
# 3    $1,588,219,925     $80,321,183,881     $80,321,183,881              1.0
# 4    $5,037,552,943     $57,901,634,688     $74,417,366,096             0.78
# ..              ...                 ...                 ...              ...
# 95     $333,615,649        $905,596,275     $47,879,776,889             0.02
# 96      $37,882,502        $902,820,408        $903,988,037              1.0
# 97      $10,085,895        $893,073,560      $2,005,577,636             0.45
# 98      $58,577,760        $885,480,117      $1,233,059,229             0.72
# 99     $117,486,418        $878,962,760     $12,073,664,284             0.07
#
#    Currency Code
# 0            BTC
# 1            ETH
# 2           USDT
# 3            BNB
# 4            SOL
# ..           ...
# 95           WLD
# 96           SNX
# 97            GT
# 98           CFX
# 99          STRK
#
# [100 rows x 12 columns]

# %%
#5:10PM,Wednesday 17th, 2024

df2.to_csv("/Users/mac/Documents/DA/Python/CoingeckoData.csv", index = False)
